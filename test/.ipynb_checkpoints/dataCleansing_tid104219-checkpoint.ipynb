# %% [markdown]
# # dataCleansing tid-20174

# %%
import pytest
import os,sys
import itertools
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem.Descriptors import MolWt
from rdkit.Chem.Scaffolds import MurckoScaffold
#sys.path.append(os.path.join(os.path.dirname(__file__), '../src/'))
sys.path.append('../')
from sphg.infra.xmol import xmol
from sphg.common.graph import Graph
from sphg.common.unique import unique
from sphg.common.scaffold import Scaffold
from sphg.common import pickle0
#from infra.phcg import LPhcg
#from database.ligand import Ligand
import sphg.common.molwt as molwt

# %% [markdown]
# | TID    | CHEMBLID   | Name                           | Uniprot |
# | -----  | ---------- | ------------------------------ | ------- |
# | 8      | CHEMBL1862 | Tyrosine  kinase ABL1          | P00519  |
# | 11     | CHEMBL204  | Thrombin                       | P00734  |
# | 137    | CHEMBL237  | 𝜅-opioid  receptor             | P41145  |
# | 11362  | CHEMBL4005 | PI3-kinase  p110-alpha subunit | N/A     |
# | 20174  | N/A  | G protein-coupled receptor 44          | N/A     |
# | 104219 | N/A  | Transmembrane protease serine 6      | N/A     |

# %%
tid=20174
tsvdir='../../data/sphg/tid-%d/'%tid
files=os.listdir(tsvdir)
files
# Out:
# ['tid-20174-actives.txt', 'tid-20174-inactives.txt']

# %%
dfactives=pd.read_csv(tsvdir+'tid-%d-actives.txt'%tid,delimiter='\t')
dfinactives=pd.read_csv(tsvdir+'tid-%d-inactives.txt'%tid,delimiter='\t')

# %%
dfactives
# Out:
#      funatsu_lab_id      chembl-id  pot.(log,Ki)  pot.(nMol,Ki)  \
# 0           1556435  CHEMBL3639847         10.00            0.1
# 1           1560497  CHEMBL3690164         10.00            0.1
# 2           1560498  CHEMBL3690165         10.00            0.1
# 3           1560510  CHEMBL3690177         10.00            0.1
# 4           1560511  CHEMBL3690178         10.00            0.1
# ..              ...            ...           ...            ...
# 855          259538   CHEMBL180732          4.77        17000.0
# 856          259522   CHEMBL360147          4.74        18000.0
# 857          259602   CHEMBL426240          4.72        19000.0
# 858          259450   CHEMBL180098          4.57        27000.0
# 859          259430   CHEMBL359875          4.48        33000.0
#
#                                        aromatic_smiles  \
# 0    Cc1c2cc(ccc2[nH]c1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)...
# 1    CCCn1c2cc(ccc2cc1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)C...
# 2    CCn1c2cc(ccc2cc1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)C)...
# 3    CCn1c2cc(ccc2cc1C(=O)Nc3ccc(c(c3)F)Cn4c(c(c(n4...
# 4    CCCn1c2cc(ccc2cc1C(=O)Nc3ccc(c(c3)F)Cn4c(c(c(n...
# ..                                                 ...
# 855        c1ccc(cc1)CNc2ccc3c(c2)c4c(n3CCC(=O)O)CCCC4
# 856  CCC(C(=O)O)n1c2ccc(cc2c3c1CCCC3)NS(=O)(=O)c4cc...
# 857  c1cc(ccc1F)S(=O)(=O)Nc2ccc3c(c2)c4c(n3/C=C\C(=...
# 858  c1cc(cc(c1)n2c3ccc(cc3c4c2CCCC4)NS(=O)(=O)c5cc...
# 859  c1ccc(c(c1)C(=O)O)n2c3ccc(cc3c4c2CCCC4)NS(=O)(...
#
#                             non_stereo_aromatic_smiles all-chembl-ids  \
# 0    Cc1c2cc(ccc2[nH]c1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)...  CHEMBL3639847
# 1    CCCn1c2cc(ccc2cc1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)C...  CHEMBL3690164
# 2    CCn1c2cc(ccc2cc1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)C)...  CHEMBL3690165
# 3    CCn1c2cc(ccc2cc1C(=O)Nc3ccc(c(c3)F)Cn4c(c(c(n4...  CHEMBL3690177
# 4    CCCn1c2cc(ccc2cc1C(=O)Nc3ccc(c(c3)F)Cn4c(c(c(n...  CHEMBL3690178
# ..                                                 ...            ...
# 855        c1ccc(cc1)CNc2ccc3c(c2)c4c(n3CCC(=O)O)CCCC4   CHEMBL180732
# 856  CCC(C(=O)O)n1c2ccc(cc2c3c1CCCC3)NS(=O)(=O)c4cc...   CHEMBL360147
# 857  c1cc(ccc1F)S(=O)(=O)Nc2ccc3c(c2)c4c(n3C=CC(=O)...   CHEMBL426240
# 858  c1cc(cc(c1)n2c3ccc(cc3c4c2CCCC4)NS(=O)(=O)c5cc...   CHEMBL180098
# 859  c1ccc(c(c1)C(=O)O)n2c3ccc(cc3c4c2CCCC4)NS(=O)(...   CHEMBL359875
#
#      no.-meas.
# 0            2
# 1            2
# 2            2
# 3            2
# 4            2
# ..         ...
# 855          1
# 856          1
# 857          1
# 858          1
# 859          1
#
# [860 rows x 8 columns]

# %%
dfinactives
# Out:
#     funatsu_lab_id      chembl-id           potencies  \
# 0           308524   CHEMBL379639    5200.0,None,None
# 1           308464   CHEMBL378666           21.0,None
# 2           308430   CHEMBL378094          125.0,None
# 3          1246815  CHEMBL2385123                None
# 4          1246584  CHEMBL2385111                None
# 5           308280   CHEMBL378730            2.3,None
# 6           308334   CHEMBL213495           18.0,None
# 7          1283736  CHEMBL3099128                None
# 8          1381409  CHEMBL3338264                None
# 9          1381410  CHEMBL3338265                None
# 10          308697   CHEMBL214350            6.0,None
# 11         1381412  CHEMBL3338266                None
# 12         1381407  CHEMBL3338262                None
# 13          308465   CHEMBL211677           18.0,None
# 14         1246811  CHEMBL2385119                None
# 15         1112636  CHEMBL2036222  3.2,None,46.0,85.0
# 16          308696   CHEMBL214304            5.4,None
# 17          308310   CHEMBL211631           11.0,None
# 18         1283732  CHEMBL3099125                None
# 19          308431   CHEMBL212777            8.0,None
# 20         1283706  CHEMBL3099100                None
# 21          909996  CHEMBL1689116                None
# 22          308309   CHEMBL213854            7.1,None
# 23          308402   CHEMBL213029     180.0,None,None
# 24         1041957  CHEMBL1917796            7.0,None
# 25         1283735  CHEMBL3099127                None
# 26         1381405  CHEMBL3338260                None
# 27          308493   CHEMBL384962           68.0,None
# 28          308403   CHEMBL379828           50.0,None
# 29          308279   CHEMBL209689            2.6,None
# 30          308333   CHEMBL213494           23.0,None
#
#                       units  \
# 0    IC50,Activity,Activity
# 1             IC50,Activity
# 2             IC50,Activity
# 3                      IC50
# 4                      IC50
# 5             IC50,Activity
# 6             IC50,Activity
# 7                      IC50
# 8                      IC50
# 9                      IC50
# 10            IC50,Activity
# 11                     IC50
# 12                     IC50
# 13            IC50,Activity
# 14                     IC50
# 15  Ki,Emax,IC50,Inhibition
# 16            IC50,Activity
# 17            IC50,Activity
# 18                     IC50
# 19            IC50,Activity
# 20                     IC50
# 21               Inhibition
# 22            IC50,Activity
# 23   IC50,Activity,Activity
# 24              Ki,Activity
# 25                     IC50
# 26                     IC50
# 27            IC50,Activity
# 28            IC50,Activity
# 29            IC50,Activity
# 30            IC50,Activity
#
#                                       aromatic_smiles  \
# 0                     Cc1c(c2ccccc2n1c3ccncn3)CC(=O)O
# 1          Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4
# 2      Cc1ccc2c(c1)n(c(c2c3ccnc4c3ccc(c4)Cl)C)CC(=O)O
# 3    Cc1c(c(nn1Cc2ccc(cc2)S(=O)(=O)C)c3ccccc3)CC(=O)O
# 4   Cc1c(c(nn1CC2CCCN2S(=O)(=O)c3ccccc3)c4ccccc4)C...
# 5        Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4Cl
# 6       Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4C#N
# 7     Cc1c(c(nn1CC(=O)O)OC)Cc2ccccc2S(=O)(=O)c3ccccc3
# 8   Cc1ccc2c(cn(c2n1)c3ccc(cc3Cc4cc(nn4C)C)Cl)CC(=O)O
# 9       Cc1ccc2c(cn(c2n1)c3ccccc3Cn4cc(nc4C)C)CC(=O)O
# 10  Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4C(F)...
# 11    Cc1ccc2c(cn(c2n1)c3ccccc3Cn4c(nc(n4)C)C)CC(=O)O
# 12   COc1ccc(cc1c2ccc(cc2Cn3ccccc3=O)C(F)(F)F)CC(=O)O
# 13      Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3cc(nc4c3cccc4)C
# 14  Cc1c(c(nn1C(c2ccc(cc2)F)c3ccc(cc3)F)c4ccc(nc4)...
# 15  CC(C)CC(=O)N(Cc1ccc(cc1)S(=O)(=O)C)c2cc(cc(c2)...
# 16  Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3ccc(c4)C(...
# 17       Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4OC
# 18  Cc1c(c(nn1CC(=O)O)c2ccccc2)Cc3ccccc3c4cccc5c4c...
# 19     Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3ccc(c4)Cl
# 20  Cc1c(c(nn1CC(=O)O)c2ccc(cc2)C(=O)N(C)C)Cc3cccc...
# 21  c1ccc(cc1)S(=O)(=O)C2CCN(CC2)Cc3cc(ccc3OCC(=O)...
# 22        Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4F
# 23      Cc1c(c2cc(ccc2n1c3ccnc4c3ccc(c4)Cl)OC)CC(=O)O
# 24  CCCS(=O)(=O)c1ccc(c(c1)C#Cc2cc(ccc2OCC(=O)O)C#N)C
# 25  Cc1c(c(=O)[nH]n1CC(=O)O)Cc2ccccc2S(=O)(=O)c3cc...
# 26  Cc1ccc2c(cn(c2n1)c3ccc(cc3CSC(C)(C)C)C(F)(F)F)...
# 27  Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cc(cc4)C(...
# 28      Cc1c(c2cc(ccc2n1CC(=O)O)OC)c3ccnc4c3ccc(c4)Cl
# 29        Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4C
# 30  Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4S(=O...
#
#                            non_stereo_aromatic_smiles all-chembl-ids  \
# 0                     Cc1c(c2ccccc2n1c3ccncn3)CC(=O)O   CHEMBL379639
# 1          Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4   CHEMBL378666
# 2      Cc1ccc2c(c1)n(c(c2c3ccnc4c3ccc(c4)Cl)C)CC(=O)O   CHEMBL378094
# 3    Cc1c(c(nn1Cc2ccc(cc2)S(=O)(=O)C)c3ccccc3)CC(=O)O  CHEMBL2385123
# 4   Cc1c(c(nn1CC2CCCN2S(=O)(=O)c3ccccc3)c4ccccc4)C...  CHEMBL2385111
# 5        Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4Cl   CHEMBL378730
# 6       Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4C#N   CHEMBL213495
# 7     Cc1c(c(nn1CC(=O)O)OC)Cc2ccccc2S(=O)(=O)c3ccccc3  CHEMBL3099128
# 8   Cc1ccc2c(cn(c2n1)c3ccc(cc3Cc4cc(nn4C)C)Cl)CC(=O)O  CHEMBL3338264
# 9       Cc1ccc2c(cn(c2n1)c3ccccc3Cn4cc(nc4C)C)CC(=O)O  CHEMBL3338265
# 10  Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4C(F)...   CHEMBL214350
# 11    Cc1ccc2c(cn(c2n1)c3ccccc3Cn4c(nc(n4)C)C)CC(=O)O  CHEMBL3338266
# 12   COc1ccc(cc1c2ccc(cc2Cn3ccccc3=O)C(F)(F)F)CC(=O)O  CHEMBL3338262
# 13      Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3cc(nc4c3cccc4)C   CHEMBL211677
# 14  Cc1c(c(nn1C(c2ccc(cc2)F)c3ccc(cc3)F)c4ccc(nc4)...  CHEMBL2385119
# 15  CC(C)CC(=O)N(Cc1ccc(cc1)S(=O)(=O)C)c2cc(cc(c2)...  CHEMBL2036222
# 16  Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3ccc(c4)C(...   CHEMBL214304
# 17       Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4OC   CHEMBL211631
# 18  Cc1c(c(nn1CC(=O)O)c2ccccc2)Cc3ccccc3c4cccc5c4c...  CHEMBL3099125
# 19     Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3ccc(c4)Cl   CHEMBL212777
# 20  Cc1c(c(nn1CC(=O)O)c2ccc(cc2)C(=O)N(C)C)Cc3cccc...  CHEMBL3099100
# 21  c1ccc(cc1)S(=O)(=O)C2CCN(CC2)Cc3cc(ccc3OCC(=O)...  CHEMBL1689116
# 22        Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4F   CHEMBL213854
# 23      Cc1c(c2cc(ccc2n1c3ccnc4c3ccc(c4)Cl)OC)CC(=O)O   CHEMBL213029
# 24  CCCS(=O)(=O)c1ccc(c(c1)C#Cc2cc(ccc2OCC(=O)O)C#N)C  CHEMBL1917796
# 25  Cc1c(c(=O)[nH]n1CC(=O)O)Cc2ccccc2S(=O)(=O)c3cc...  CHEMBL3099127
# 26  Cc1ccc2c(cn(c2n1)c3ccc(cc3CSC(C)(C)C)C(F)(F)F)...  CHEMBL3338260
# 27  Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cc(cc4)C(...   CHEMBL384962
# 28      Cc1c(c2cc(ccc2n1CC(=O)O)OC)c3ccnc4c3ccc(c4)Cl   CHEMBL379828
# 29        Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4C   CHEMBL209689
# 30  Cc1ccc2c(c1)c(c(n2CC(=O)O)C)c3ccnc4c3cccc4S(=O...   CHEMBL213494
#
#                            activity-comment
# 0   [None, 'Partial agonist', 'Not Active']
# 1                      [None, 'Not Active']
# 2                      [None, 'Not Active']
# 3                            ['Not Active']
# 4                            ['Not Active']
# 5                      [None, 'Not Active']
# 6                      [None, 'Not Active']
# 7                            ['Not Active']
# 8                            ['Not Active']
# 9                            ['Not Active']
# 10                     [None, 'Not Active']
# 11                           ['Not Active']
# 12                           ['Not Active']
# 13                     [None, 'Not Active']
# 14                           ['Not Active']
# 15         [None, 'Not Active', None, None]
# 16                     [None, 'Not Active']
# 17                     [None, 'Not Active']
# 18                           ['Not Active']
# 19                     [None, 'Not Active']
# 20                           ['Not Active']
# 21                           ['Not Active']
# 22                     [None, 'Not Active']
# 23       [None, 'Antagonist', 'Not Active']
# 24                     [None, 'Not Active']
# 25                           ['Not Active']
# 26                           ['Not Active']
# 27                     [None, 'Not Active']
# 28                     [None, 'Not Active']
# 29                     [None, 'Not Active']
# 30                     [None, 'Not Active']

# %%
smileslist=list(dfactives['non_stereo_aromatic_smiles'])
activitiylist=list(dfactives['pot.(log,Ki)'])

# %%
nmol=len(smileslist)
    #for imol, (chembl, smiles, activity) in enumerate(zip(chembl_list,smiles_list, activity_list)):
    #    if imol==44:
def showMol(index):
    imol=index
    smiles=smileslist[imol]
    mol=Chem.MolFromSmiles(smiles)
    xmol0 = xmol(mol,molid=0)
    xmol0.activity=activitiylist[imol]
    xmol0.getChemicalFeats()
    xmol0.show(grid=False,num=False)
    print('### calc. %d-th/%d activity=%6.2f'%(imol,nmol,xmol0.activity))
    print('SMILES = %s'%smiles)
    print(xmol0.featsAtomListGraph)
    print(xmol0.featsFamilyList)

# %%
from ipywidgets import interact
interact(showMol, index=(0, nmol - 1, 1))
# Out:
# interactive(children=(IntSlider(value=429, description='index', max=859), Output()), _dom_classes=('widget-int…
# <function __main__.showMol(index)>

# %%
#df1=df[['chembl-id','pot.(log,Ki)','non_stereo_aromatic_smiles']]
dfactives1=dfactives[['chembl-id','pot.(log,Ki)','non_stereo_aromatic_smiles']]
dfactives1.columns=['chembl-id','activity','smiles']
dfinactives1=dfinactives[['chembl-id','potencies','non_stereo_aromatic_smiles']]
dfinactives1.columns=['chembl-id','activity','smiles']
dfinactives1=dfinactives1[dfinactives1['activity']=='None']
dfinactives1['activity']=0.0
dfinactives1
# Out:
#         chembl-id  activity                                             smiles
# 3   CHEMBL2385123       0.0   Cc1c(c(nn1Cc2ccc(cc2)S(=O)(=O)C)c3ccccc3)CC(=O)O
# 4   CHEMBL2385111       0.0  Cc1c(c(nn1CC2CCCN2S(=O)(=O)c3ccccc3)c4ccccc4)C...
# 7   CHEMBL3099128       0.0    Cc1c(c(nn1CC(=O)O)OC)Cc2ccccc2S(=O)(=O)c3ccccc3
# 8   CHEMBL3338264       0.0  Cc1ccc2c(cn(c2n1)c3ccc(cc3Cc4cc(nn4C)C)Cl)CC(=O)O
# 9   CHEMBL3338265       0.0      Cc1ccc2c(cn(c2n1)c3ccccc3Cn4cc(nc4C)C)CC(=O)O
# 11  CHEMBL3338266       0.0    Cc1ccc2c(cn(c2n1)c3ccccc3Cn4c(nc(n4)C)C)CC(=O)O
# 12  CHEMBL3338262       0.0   COc1ccc(cc1c2ccc(cc2Cn3ccccc3=O)C(F)(F)F)CC(=O)O
# 14  CHEMBL2385119       0.0  Cc1c(c(nn1C(c2ccc(cc2)F)c3ccc(cc3)F)c4ccc(nc4)...
# 18  CHEMBL3099125       0.0  Cc1c(c(nn1CC(=O)O)c2ccccc2)Cc3ccccc3c4cccc5c4c...
# 20  CHEMBL3099100       0.0  Cc1c(c(nn1CC(=O)O)c2ccc(cc2)C(=O)N(C)C)Cc3cccc...
# 21  CHEMBL1689116       0.0  c1ccc(cc1)S(=O)(=O)C2CCN(CC2)Cc3cc(ccc3OCC(=O)...
# 25  CHEMBL3099127       0.0  Cc1c(c(=O)[nH]n1CC(=O)O)Cc2ccccc2S(=O)(=O)c3cc...
# 26  CHEMBL3338260       0.0  Cc1ccc2c(cn(c2n1)c3ccc(cc3CSC(C)(C)C)C(F)(F)F)...

# %%
dfall=pd.concat([dfactives1,dfinactives1])
dfall
# Out:
#         chembl-id  activity                                             smiles
# 0   CHEMBL3639847      10.0  Cc1c2cc(ccc2[nH]c1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)...
# 1   CHEMBL3690164      10.0  CCCn1c2cc(ccc2cc1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)C...
# 2   CHEMBL3690165      10.0  CCn1c2cc(ccc2cc1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)C)...
# 3   CHEMBL3690177      10.0  CCn1c2cc(ccc2cc1C(=O)Nc3ccc(c(c3)F)Cn4c(c(c(n4...
# 4   CHEMBL3690178      10.0  CCCn1c2cc(ccc2cc1C(=O)Nc3ccc(c(c3)F)Cn4c(c(c(n...
# ..            ...       ...                                                ...
# 18  CHEMBL3099125       0.0  Cc1c(c(nn1CC(=O)O)c2ccccc2)Cc3ccccc3c4cccc5c4c...
# 20  CHEMBL3099100       0.0  Cc1c(c(nn1CC(=O)O)c2ccc(cc2)C(=O)N(C)C)Cc3cccc...
# 21  CHEMBL1689116       0.0  c1ccc(cc1)S(=O)(=O)C2CCN(CC2)Cc3cc(ccc3OCC(=O)...
# 25  CHEMBL3099127       0.0  Cc1c(c(=O)[nH]n1CC(=O)O)Cc2ccccc2S(=O)(=O)c3cc...
# 26  CHEMBL3338260       0.0  Cc1ccc2c(cn(c2n1)c3ccc(cc3CSC(C)(C)C)C(F)(F)F)...
#
# [873 rows x 3 columns]

# %%
# delete duplicated compounds
dfall=pd.concat([dfactives1,dfinactives1])
print("Before deletion of duplicated compounds: No. of cmpounds is %d"%len(dfall))
tfvec=dfall.duplicated(subset='chembl-id',keep=False)
dfall=dfall[~tfvec]
#print(tfvec)
tfvec=dfall.duplicated(subset='smiles',keep=False)
dfall=dfall[~tfvec]
#print(tfvec)
#print(len(dfall))
print("After deletion of duplicated compounds: No. of cmpounds is %d"%len(dfall))

dfall
# Out:
# Before deletion of duplicated compounds: No. of cmpounds is 873
# After deletion of duplicated compounds: No. of cmpounds is 823
#         chembl-id  activity                                             smiles
# 0   CHEMBL3639847      10.0  Cc1c2cc(ccc2[nH]c1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)...
# 1   CHEMBL3690164      10.0  CCCn1c2cc(ccc2cc1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)C...
# 2   CHEMBL3690165      10.0  CCn1c2cc(ccc2cc1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)C)...
# 3   CHEMBL3690177      10.0  CCn1c2cc(ccc2cc1C(=O)Nc3ccc(c(c3)F)Cn4c(c(c(n4...
# 4   CHEMBL3690178      10.0  CCCn1c2cc(ccc2cc1C(=O)Nc3ccc(c(c3)F)Cn4c(c(c(n...
# ..            ...       ...                                                ...
# 18  CHEMBL3099125       0.0  Cc1c(c(nn1CC(=O)O)c2ccccc2)Cc3ccccc3c4cccc5c4c...
# 20  CHEMBL3099100       0.0  Cc1c(c(nn1CC(=O)O)c2ccc(cc2)C(=O)N(C)C)Cc3cccc...
# 21  CHEMBL1689116       0.0  c1ccc(cc1)S(=O)(=O)C2CCN(CC2)Cc3cc(ccc3OCC(=O)...
# 25  CHEMBL3099127       0.0  Cc1c(c(=O)[nH]n1CC(=O)O)Cc2ccccc2S(=O)(=O)c3cc...
# 26  CHEMBL3338260       0.0  Cc1ccc2c(cn(c2n1)c3ccc(cc3CSC(C)(C)C)C(F)(F)F)...
#
# [823 rows x 3 columns]

# %%
dfout=dfall
#dfout=df1
#dfout=df1.sample(10000,random_state=0)
dfout.to_csv(tsvdir+'tid-%d-master.csv'%tid,index=False)
dfout
# Out:
#         chembl-id  activity                                             smiles
# 0   CHEMBL3639847      10.0  Cc1c2cc(ccc2[nH]c1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)...
# 1   CHEMBL3690164      10.0  CCCn1c2cc(ccc2cc1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)C...
# 2   CHEMBL3690165      10.0  CCn1c2cc(ccc2cc1C(=O)Nc3ccc(cc3)Cn4c(c(c(n4)C)...
# 3   CHEMBL3690177      10.0  CCn1c2cc(ccc2cc1C(=O)Nc3ccc(c(c3)F)Cn4c(c(c(n4...
# 4   CHEMBL3690178      10.0  CCCn1c2cc(ccc2cc1C(=O)Nc3ccc(c(c3)F)Cn4c(c(c(n...
# ..            ...       ...                                                ...
# 18  CHEMBL3099125       0.0  Cc1c(c(nn1CC(=O)O)c2ccccc2)Cc3ccccc3c4cccc5c4c...
# 20  CHEMBL3099100       0.0  Cc1c(c(nn1CC(=O)O)c2ccc(cc2)C(=O)N(C)C)Cc3cccc...
# 21  CHEMBL1689116       0.0  c1ccc(cc1)S(=O)(=O)C2CCN(CC2)Cc3cc(ccc3OCC(=O)...
# 25  CHEMBL3099127       0.0  Cc1c(c(=O)[nH]n1CC(=O)O)Cc2ccccc2S(=O)(=O)c3cc...
# 26  CHEMBL3338260       0.0  Cc1ccc2c(cn(c2n1)c3ccc(cc3CSC(C)(C)C)C(F)(F)F)...
#
# [823 rows x 3 columns]
